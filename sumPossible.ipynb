# %%
def sum_possible(amount, numbers):
  pass # todo
  memo={}
  possible=_sum_possible(amount, numbers, memo)
  return possible

def _sum_possible(amount, numbers, memo):
  
  if amount==0:
    return True 
  
  if amount<0:
    return False
  
  if amount in memo:
    return memo[amount]
  
  for number in numbers:
    memo[amount]=_sum_possible(amount-number,numbers, memo)

    if memo[amount]:
      return True
  
  return False
