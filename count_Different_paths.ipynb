# %%
import math
def counting_change(amount, coins):
  pass # todo
  return _counting_change(amount, coins, 0)

def _counting_change(amount, coins, i):
  
  if amount==0:
    return 1
  
  if amount<0:
    return 0
  
  if i==len(coins):
    return 0
  
  out=0
  for qty in range(amount//coins[i]+1):
    out=out+_counting_change(amount-coins[i]*qty, coins, i+1)
    
    
  return out
