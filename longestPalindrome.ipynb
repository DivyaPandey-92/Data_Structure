# %%
def max_palin_subsequence(string):
  # pass # todo
  return _max_palin_subsequence(string, 0, len(string)-1)
  
def _max_palin_subsequence(string, start, end):
  if start==end:
    return 1
  if start>end:
    return 0
  
  if string[start]==string[end]:
    return 2+_max_palin_subsequence(string, start+1, end-1)
  else:
     return max(
    _max_palin_subsequence(string, start+1, end),
    _max_palin_subsequence(string, start, end-1)
     )
