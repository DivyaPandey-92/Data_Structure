# %%
def array_stepper(numbers):
  pass # todo
  return _array_stepper(numbers, 0, {})

def _array_stepper(numbers, i, memo):
  
  if i==len(numbers)-1:
    return True
  
  if numbers[i]==0 or i>len(numbers)-1:
    return False
  
  if i in memo:
    return memo[i]
    
  
  for step in range(1, numbers[i]+1):
    memo[i]=_array_stepper(numbers, i+step, memo)
